# %% [markdown]
# Учебный курс "Интеллектуальные системы"
#
# **Лабораторная работа № 4.**
# # Решение оптимизационных задач с помощью генетических алгоритмов
#
# Учебно-методическое издание «Решение оптимизационных задач с помощью генетических алгоритмов» представляет собой методические указания к выполнению лабораторной работы по курсу «Интеллектуальные системы». В ней, на примере решения оптимизационной задачи большой размерности с помощью генетического алгоритма, исследуется работа операторов деления, скрещивания и мутации. В заключение приводится список рекомендуемой к изучению литературы.
#
# **Введение**
#
# Лабораторная работа «Решение оптимизационных задач с помощью генетических алгоритмов» по курсу «Интеллектуальные системы» - это самостоятельная практическая работа студентов, которую они выполняют в 8-м семестре, в период с 14 по 17 неделю.
#
# **1.     Цель и задачи лабораторной работы**
#
# 1.1.   Целью лабораторной работы является углубление и закрепление теоретических знаний, полученных на лекциях, приобретение практических навыков самостоятельной работы при решении оптимизационных задач больших размерностей с помощью генетических алгоритмов.
# 1.2.   В процессе выполнения лабораторной работы по теме «Решение оптимизационных задач с помощью генетических алгоритмов» на примере задачи поиска кратчайшего пути для информационного пакета (сообщения) в компьютерной сети студенты решают следующие задачи (задания):
# - 	описывают предметную область;
# - 	определяют исходные данные задачи;
# - 	формулируют задачу и исходные данные в терминах генетических алгоритмов;
# - 	определяют последовательность работы генетического алгоритма;
# - 	разрабатывают компьютерную программу;
# - 	исследуют работу генетического алгоритма и полученное решение.
#
# 2.Задание к лабораторной работе
#
# 2.1. Сформулировать задачу и описать исходные данные в терминах генетических алгоритмов.
# 2.2. Разработать программу, которая осуществляет поиск кратчайшего пути для информационного пакета (сообщения) в компьютерной сети с помощью генетического алгоритма.
# 2.3. При проведения серии экспериментов (не меньше 10) по исследованию работы генетического алгоритма программа должна позволять пользователю задавать топологию сети (пропускные способности каналов связи), содержащей не менее 10 компьютеров (серверов), а также указывать компьютер-отправитель и компьютер-получатель. Должны отображаться все решения (хромосомы) одного поколения до и после применения каждого оператора (скрещивания, селекции, редукции и мутации). Переход к следующему поколению должен осуществляться: в автоматическом режиме в соответствии с заданным критерием; в ручном режиме.
#
# **Рекомендации**
#
# А) В качестве хромосомы выбрать постоянную по длине последовательность вершин или дуг. Длина дуги - произвольная, но не меньше, чем N–2, где N –общее количество компьютеров в сети.
# Б) Для упрощения расчетов граф сети следует сделать полносвязным (каждая пара вершин имеет связь). При отсутствии связи (соединения) вес дуги следует выбрать очень большим, а для петли (дуги, соединяющей вершину с самой собой) – значение веса равное 0. Это позволит искать пути, меньшие по длине, чем размер хромосомы.
# В) Если в качестве хромосомы используется последовательность вершин (узлов сети), то необходимо либо:
# - исключить первую и последнюю вершину (т.е. задавать только вершины пути);
# - либо не изменять в результате применения генетических операторов первую и последнюю вершины;
# - либо реализовать направленный оператор мутации, который всегда устанавливает заданные на входе вершины, соответствующие компьютеру-отправителю и компьютеру-получателю.
# Г)  В качестве генов допускается использование чисел в десятеричной системе. В этом случае рекомендуется количество серверов брать равное 10 (номера 0-9). Если используется битовая строка, то для удобства лучше выбрать количество серверов равное 2n (16, 32, 64 и т.д.). Это позволит избежать формирования в результате скрещивания и мутации несуществующих номеров вершин (узлов, серверов).
# Д)  Если в исходной популяции не представлены все возможные вершины (гены), то они могут появиться только в результате мутации, поэтому рекомендуется в начальной выборке представить весь генофонд.
# Е)  Если выбранный алгоритм скрещивания меняет только правую (левую) часть хромосомы или только 4 гена из 10, то его эффективность невысока (т.к. часть генов не будет изменяться), а получение решения в большей степени будет зависеть от оператора мутации и начальной популяции, сформированной случайным образом.
#
# **3.  	Содержание отчета по лабораторной работы**
#
# 3.1.   Название и цель работы.
# 3.2.   Задание.
# 3.3.   Описание предметной области и выбранной задачи.
# 3.4.   Формулировка задачи, описание исходных данных в терминах генетических алгоритмов и блок-схема генетического алгоритма.
# 3.5.   Описание программы, ее ключевые особенности и новшества.
# 3.6.   Протоколы проведенных экспериментов.
# 3.7.   Выводы.
# 3.8.   Используемая литература.
#
# **4.      Порядок выполнения работы**
#
# 4.1.   Изучить теоретические положения по работе и применению генетических алгоритмов.
# 4.2.   Последовательно выполнить все задания лабораторной работы в соответствии с п. 2, 3.
# 4.3.   Обосновать правильность решения на основе анализа не менее чем 10 примеров. Сделать выводы.
# 4.4.   Оформить отчет по лабораторной работе в соответствии с п. 3.
#
# **Сроки получения, сдачи и порядок защиты лабораторной работы**
#
# Лабораторная работа выполняется в период с 14 по 17 неделю. Вопросы выбора модификации, определения параметров операторов генетического алгоритма, критерии отбора и т.д. согласовываются с преподавателем на консультациях.
# К защите лабораторной работы необходимо представить:
# 1.  Отчет по лабораторной работе в бумажном и электронном виде.
# 2.  Презентацию защиты лабораторной работы (в формате .pptx, объемом 6-8 слайдов, структура – см. п. 3), в краткой форме представляющая основные результаты проведенного исследования.
# Особое внимание при защите следует уделить формулировке выводов, которые должны отражать основные полученные результаты работы, возникшие трудности и теоретические пути их преодоления.
# В особых случаях, после предварительных консультаций, преподаватель может самостоятельно определять студентам предметную область, постановку и исходные данные задач повышенной трудности. При этом порядок защиты работы не меняется, а сроки ее выполнения согласовываются.

# %% [markdown]
# ## Pipeline выполнения задания

# %% [markdown]
# **1. Предметная область**
# Для начала необходимо определиться с предметной областью и терминами в ней.
# У каждого компьютера в сети есть свой уникальный номер. Нумерация начинается с 0.
# Зададим номера компьютера-отправителя информационного пакета и компьютера-получателя, а так же кол-во компьютеров в сети

# %%
sender = # номер компьютера-отправителя
receiver = # номер компьютера-получателя
num_comps = # кол-во компьютеров в сети

# %% [markdown]
# Примем, что сеть является полносвязной. Зададим пропусные способности канало связи в виде матрицы.
# Для того чтобы в конце могли быть пути, например только с одним копьютером, сделаем пропускную способность компьютера самому себе бесконечной, и запишем 9999999

# %%
inputs = [[9999999, 1, 2, 3, 4, 5, 6, 7, 8, 9],
          [1, 9999999, 2, 3, 4, 5, 6, 7, 8, 9],
          [2, 1, 9999999, 3, 4, 5, 6, 7, 8, 9],
          [3, 1, 2, 9999999, 4, 5, 6, 7, 8, 9],
          [4, 1, 2, 3, 9999999, 5, 6, 7, 8, 9],
          [5, 1, 2, 3, 4, 9999999, 6, 7, 8, 9],
          [6, 1, 2, 3, 4, 5, 9999999, 7, 8, 9],
          [7, 1, 2, 3, 4, 5, 6, 9999999, 8, 9],
          [8, 1, 2, 3, 4, 5, 6, 7, 9999999, 9],
          [9, 1, 2, 3, 4, 5, 6, 7, 8, 9999999]]
# пример заполнения пропускных способностей для сети из 10 компьютеров

# %% [markdown]
# Или можно сделать случайную матрицу пропускных способностей с помощью функции input_weight

# %%
import numpy

def input_weight(num_comps):
    equation_inputs = numpy.empty((num_comps,num_comps))
    for i in range(num_comps):
        for j in range(i, num_comps):
            if i == j:
                equation_inputs[i][j] = 9999999
                continue
            equation_inputs[i][j] = equation_inputs[j][i] = numpy.random.uniform(0.000001, 1000, 1)
    print(equation_inputs)
    return equation_inputs

# %% [markdown]
# Далее необходимо разобраться с хромосомой и популяцией
# Как хромосома - состоит из генов, так и путь информационного пакета состоит из номеров компьютеров.
# Итог: хромосома - путь, ген - номер компьютера.
# Популяция состоит из разных хромосом (путей), чем больше их количество и вариативность, тем лучше
# Зададим количество генов в хромосоме и количество хромосом в популяции

# %%
num_comps = # количество генов в хромосоме
pop_size = # количество хромосом в популяции

# %% [markdown]
# Как пример создания популяции рассмотрим функцию create_population. Она принимает на вход номера компьютера отправителя и получателя, общее количесвто в популяции и размер популяции.
# В ее работе принято ограничение - номера компьютера отправителя и получателя не могут быть в пути сообщения.
#
# **Надо ли вообще приводить полный текст этой функции??????????**

# %%
import random

def create_population(sender, receiver, num_comps, pop_size):
    num_hubs = [i for i in range(0, num_comps) if i!=sender and i!=receiver] # вычисляются номера компьютеров без отправителя и получателя
    # получается что если 15 генов максимальный номер мб 15 а компов то у нас было 10
    # надо прописать еще одно ограничение на кол-во генов??????
    len_hubs = len(num_hubs)
    population = [] # начальный массив популяции
    for i in range(pop_size):
        elem = [num_hubs[numpy.random.randint(len_hubs)] for j in range(len_hubs)] # гены в хромосоме задаются случайным образом
        population.append(elem)
    return numpy.array(population)

# %% [markdown]
# **2. Алгоритм**
# Начальный этап пройден! Популяция задана. Теперь необходимо разобраться с работой самого алгоритма.
# Основная идея состоит в том, чтобы после каждого раунда тестирования или моделирования удалить n наихудших исследуемых решений(хромосом) и ввести в популяцию n новых решений(хромосом). Для реализации данного метода каждому исследуемому решению должно соответствовать определенное значение, которое указывает насколько близко решение подходит к искомому значению, указанное значение получается путем применения функция приспособленности.
# Алгоритм состоит из нескольких функций.
# 1. Функция приспосрбленности - cal_pop_fitness - функция, подлежащая оптимизации в результате работы генетического алгоритма, направляет эволюцию в сторону оптимального решения. Например, можно минимизировать время передачи сообщения, вычисляемое как константа / пропускная способность. Возвращает массив из приспособленностей хромосом.

# %%
def cal_pop_fitness():
    # вычисление функции приспособленности для кадой хромосомы
    return

# %% [markdown]
# 2. Функция селекции - select_mating_pool - На этапе отбора нужно из всей популяции выбрать определённую её долю, которая останется «в живых» на этом этапе эволюции. Есть разные способы проводить отбор. Вероятность выживания особи h должна зависеть от значения функции приспособленности cal_pop_fitness(h). Сама доля выживших s обычно является параметром генетического алгоритма, и её просто задают заранее. По итогам отбора из N особей популяции H должны остаться sN особей, которые войдут в итоговую популяцию H'. Остальные особи погибают.

# %%
num_parents = # количество наилучших хромосом

def select_mating_pool('''population, fitness, num_parents'''):
    #  Например, выбор хромосомы может зависеть от ее места в популяции отсортированной по значению функции приспособленности
    return # хромосомы, из которых будет составлено новое поколение

# %% [markdown]
# 3. Функция скрещивания - crossover - создание нового поколения на основе выбранных в select_mating_pool хромосом.
#     Главное требование к размножению — чтобы потомок или потомки имели возможность унаследовать черты обоих родителей, «смешав» их каким-либо способом. Почему особи для размножения обычно выбираются из всей популяции H, а не из выживших на первом шаге элементов H' (хотя последний вариант тоже имеет право на существование)? Дело в том, что главный недостаток многих генетических алгоритмов — отсутствие разнообразия (diversity) в особях. Достаточно быстро выделяется один-единственный генотип, который представляет собой локальный максимум, а затем все элементы популяции проигрывают ему отбор, и вся популяция «забивается» копиями этой особи.
#     Есть разные способы борьбы с таким нежелательным эффектом; один из них — выбор для размножения не самых приспособленных, но вообще всех особей. Однако такой подход вынуждает хранить всех существовавших ранее особей, что увеличивает вычислительную сложность задачи. Поэтому часто применяют методы отбора особей для скрещивания таким образом, чтобы «размножались» не только самые приспособленные, но и другие особи, обладающие плохой приспособленностью. При таком подходе для разнообразия генотипа возрастает роль мутаций.

# %%
def crossover():
    '''
    Для большей вариативности можно выбирать одного родителя из функции селекции, а другого из общей популяции
    Как составлять потомка?
    1. из двух половин родителей,
    2. случайным образом выбирать какие гены перейдут от одного родителя, а какие от другого
    '''
    return # новое поколение

# %% [markdown]
# 4. Функция мутации - mutation. К мутациям относится все то же самое, что и к размножению: есть некоторая доля мутантов m, являющаяся параметром генетического алгоритма, и на шаге мутаций нужно выбрать mN особей, а затем изменить их в соответствии с заранее определёнными операциями мутации.
#
# Мутация повышает вариативность популяции, не давая ей скатиться в локальный минимум

# %%
num_mutations = # количество мутантов в популяции

def mutation(offspring_crossover, num_mutations=1):
    '''
    Мутации могут быть подвержены случайные n хромосом в популяции
    Стратегии мутации:
    1. перемешать все гены в хромосоме
    2. перемешать случайные гены в хромосоме
    3. добавить константу к некоторым генам
    '''
    return # новое поколение с мутацией

# %% [markdown]
# **3. Тестирование работы алгоритма**
# Рассмотренный выше алгоритм повторяется итеративно, так моделируется «эволюционный процесс», продолжающийся несколько жизненных циклов (поколений), пока не будет выполнен критерий остановки алгоритма. Таким критерием может быть:
#
# 1. нахождение глобального, либо субоптимального решения;
# 2. исчерпание числа поколений, отпущенных на эволюцию;
# 3. исчерпание времени, отпущенного на эволюцию.

# %%
# создадим новую популяцию
new_population = create_population()
# создадим список для лучшего значения функции приспособленности в каждом поколении
best_outputs = []
# зададим критерий остановки алгоритма - количесвто поколений
num_generations = 
# Нужно писать в консоль промежуточные результаты?
print_log = True

# запустим алгоритм
for generation in range(num_generations):
    print("Generation : ", generation)
    fitness = cal_pop_fitness()
    if print_log:
        print("Fitness")
        print(fitness)

    best_outputs.append('''Лучшее значение fitness numpy.min(fitness) или numpy.max(fitness)''')
    print("Best result : ", '''Лучшее значение fitness''')
    
    parents = select_mating_pool()
    if print_log:
        print("Parents")
        print(parents)

    offspring_crossover = crossover()
    if print_log:
        print("Crossover")
        print(offspring_crossover)

    offspring_mutation = mutation()
    if print_log:
        print("Mutation")
        print(offspring_mutation)

    # новое поколение
    new_population[0:parents.shape[0], :] = parents
    new_population[parents.shape[0]:, :] = offspring_mutation
# лучшая хромосома и лучшее значение fitness    
fitness = # лучший фитнесс
best_match_idx = # индекс лучшей хромосомы 

print("Best solution : ", new_population[best_match_idx, :])
print("Best solution fitness : ", fitness[best_match_idx])

# Построим график функции cal_pop_fitness

import matplotlib.pyplot
matplotlib.pyplot.plot(best_outputs)
matplotlib.pyplot.xlabel("Iteration")
matplotlib.pyplot.ylabel("Fitness")
matplotlib.pyplot.show()
